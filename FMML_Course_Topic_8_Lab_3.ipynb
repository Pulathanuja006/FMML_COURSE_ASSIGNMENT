# %% [markdown]
# <a href="https://colab.research.google.com/github/Pulathanuja006/FMML_COURSE_ASSIGNMENT/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-28 16:59:28--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   118MB/s    in 0.6s
#
# 2024-03-28 16:59:29 (118 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 1116   1711.02282v1  We propose a novel method to directly learn a ...  stat
# 32231   1305.1359v1  We consider the classical question of predicti...    cs
# 31194  1802.06960v1  This paper proposes an Agile Aggregating Multi...    cs
# 9321   1505.01539v1  Potential games, originally introduced in the ...    cs
# 12673  1505.00855v1  In the past few years, the number of fine-art ...    cs
# ...             ...                                                ...   ...
# 11284  1507.03194v2  Nonnegative Matrix Factorization (NMF) was fir...  stat
# 22704  1705.00956v3  We consider a class of misspecified dynamical ...  stat
# 14159  1802.01016v1  With recent trend of wearable devices and Inte...    cs
# 21547   1005.0928v2  We introduce an efficient method for training ...  stat
# 38823  1505.05225v1  Image aesthetic evaluation has attracted much ...    cs
#
#                                                    title  year  \
# 1116   Variational Walkback: Learning a Transition Op...  2017
# 32231  A Differential Equations Approach to Optimizin...  2013
# 31194  Agile Amulet: Real-Time Salient Object Detecti...  2018
# 9321                           Graphical Potential Games  2015
# 12673  Large-scale Classification of Fine-Art Paintin...  2015
# ...                                                  ...   ...
# 11284  A Review of Nonnegative Matrix Factorization M...  2015
# 22704  Experimental Design for Non-Parametric Correct...  2017
# 14159  An Area and Energy Efficient Design of Domain-...  2018
# 21547  Training linear ranking SVMs in linearithmic t...  2010
# 38823  Image aesthetic evaluation using paralleled de...  2015
#
#                                                 keywords
# 1116   [stochastic, transition, application, generate...
# 32231  [classical, predicting, sequences, algorithms,...
# 31194  [aggregating, framework, detection, convolutio...
# 9321   [potential, originally, introduced, economics,...
# 12673  [collections, digitized, available, availabili...
# ...                                                  ...
# 11284  [nonnegative, factorization, introduced, appro...
# 22704  [misspecified, dynamical, governing, approxima...
# 14159  [attractive, convolutional, applications, powe...
# 21547  [introduce, efficient, optimization, subgradie...
# 38823  [aesthetic, evaluation, attracted, attention, ...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 1116     [stochastic, transition, application, generate...
# 32231    [classical, predicting, sequences, algorithms,...
# 31194    [aggregating, framework, detection, convolutio...
# 9321     [potential, originally, introduced, economics,...
# 12673    [collections, digitized, available, availabili...
#                                ...
# 30760    [detection, significant, convolutional, detect...
# 36393    [constraint, programming, typically, optimizat...
# 39617    [architecture, perceiving, configurations, arc...
# 31722               [efficient, optimization, convergence]
# 13884    [introduce, algorithm, backpropagation, accumu...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8874 words.
# Out of those 4553 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="95920a7f-4ef8-42cd-aa4e-9e03f03e2f7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("95920a7f-4ef8-42cd-aa4e-9e03f03e2f7e")) {                    Plotly.newPlot(                        "95920a7f-4ef8-42cd-aa4e-9e03f03e2f7e",                        [{"x":["stationary","parameterized","condition","arbitrarily","objective","generated","distributions","plausible","graphical","encourages","biological","experimental","dynamical","distribution","illustrating","transition","operators","stochastic","trajectories","continues","guarantee","traditional","symmetric","corresponding","biologically","trajectory","application","undirected","variational","equilibrium","expressing","indirectly","soundness","asymmetric","restrictive","principled","recurrent","demonstrating","comparable","equivalent","discounted","negligible","different","solutions","obtaining","magnitude","functions","specified","important","algorithm","characterization","equations","essentially","qualitatively","optimizing","differential","classical","sequences","algorithms","predicting","simultaneously","aggregate","quantitative","complementary","prediction","integrated","parameters","contextual","attention","innovations","highlight","framework","effectively","specifically","detection","introduce","evaluation","qualitative","mechanism","significantly","convolutional","performance","benchmarks","aggregating","considered","establishing","presented","including","intelligence","instances","relaxation","convergence","potential","segmentation","properties","applicability","affiliation","contribution","leveraging","artificial","probabilistic","strategies","introduced","introduces","coordination","economics","literature","existence","engineering","interaction","distinguishes","distributed","congestion","allocation","equilibria","characterizations","originally","particularly","judgments","investigate","approaches","historical","optimized","appropriate","paintings","measuring","available","availability","aesthetic","digitized","classification","essential","multimedia","providing","collections","experiments","similarity","comprehensive","interpretation","knowledge","aforementioned","architecture","generalization","recognize","predefined","background","proposing","spatially","explicitly","commercial","experienced","suitability","interactions","localizing","illumination","localization","intuition","exploited","unrealistic","necessary","deployment","categories","applications","adaptation","conditions","flexibility","rationale","effectiveness","computational","techniques","information","incorporate","regression","regularization","efficiency","supervised","correctness","substantial","nonlinear","structure","statistical","unfortunately","representations","demonstrate","difficult","multilingual","discussed","sometimes","challenges","convenience","themselves","occasions","challenging","processing","analyzing","classifiers","preserved","misclassified","identification","platforms"],"y":[16,14,65,19,152,179,108,12,44,12,37,403,22,234,8,47,45,134,27,5,38,190,21,120,9,34,255,11,51,11,10,1,4,10,8,27,147,28,93,52,9,12,722,144,29,68,194,38,396,785,31,24,28,25,44,26,106,104,592,76,123,21,67,38,235,67,235,52,162,5,22,551,111,183,338,331,263,71,105,266,412,882,92,17,123,13,198,262,80,104,14,129,150,196,220,42,1,83,53,118,159,95,126,85,9,8,116,33,44,89,6,77,9,24,4,6,19,90,9,140,440,26,59,86,5,32,283,17,8,2,513,66,16,97,20,609,143,60,48,336,14,226,101,40,10,70,22,30,65,20,12,13,68,9,47,56,18,38,9,75,31,72,457,56,157,36,5,211,300,383,679,69,126,87,158,191,12,38,55,320,148,29,236,550,124,19,57,27,128,3,17,3,263,261,75,96,15,4,111,31],"type":"bar"},{"x":["stationary","parameterized","condition","arbitra ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4553,), (4553, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7916666666666666

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>Global</span> <span style=''>Warming</span> <span style=''>(Softening</span> <span style=''>Global</span> <span style=''>Constraints)</span> <br/><br/><span style=''>We</span> <span style=''>describe</span> <span style=''>soft</span> <span style=''>versions</span> <span style=''>of</span> <span style=''>the</span> <span style=''>global</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>cardinality</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraint</span> <span style=''>and</span> <span style=''>the</span> <span style=''>regular</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraint</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficient</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>filtering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>maintaining</span> <span style=''>domain</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>consistency</span> <span style=''>For</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>the</span> <span style=''>softening</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>by</span> <span style='background-color:rgba(0, 255, 0, 0.4545454545454546);'>augmenting</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>underlying</span> <span style=''>graph</span> <span style=''>The</span> <span style=''>softened</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraints</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>extend</span> <span style=''>the</span> <span style=''>meta</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraint</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>over</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>constrained</span> <span style=''>problems</span> <span style=''>proposed</span> <span style=''>by</span> <span style=''>Petit</span> <span style=''>Regin</span> <span style=''>and</span> <span style=''>Bessiere</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Markov</span> <span style=''>Chain</span> <span style=''>Lifting</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Distributed</span> <span style=''>ADMM</span> <br/><br/><span style=''>The</span> <span style=''>time</span> <span style=''>to</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>the</span> <span style=''>steady</span> <span style=''>state</span> <span style=''>of</span> <span style=''>a</span> <span style=''>finite</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>can</span> <span style=''>be</span> <span style=''>greatly</span> <span style=''>reduced</span> <span style=''>by</span> <span style=''>a</span> <span style=''>lifting</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operation</span> <span style=''>which</span> <span style=''>creates</span> <span style=''>a</span> <span style=''>new</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>on</span> <span style=''>an</span> <span style=''>expanded</span> <span style=''>state</span> <span style=''>space</span> <span style=''>For</span> <span style=''>a</span> <span style=''>class</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>quadratic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>objectives</span> <span style=''>we</span> <span style=''>show</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>analogous</span> <span style=''>behavior</span> <span style=''>where</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>distributed</span> <span style=''>ADMM</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>can</span> <span style=''>be</span> <span style=''>seen</span> <span style=''>as</span> <span style=''>a</span> <span style=''>lifting</span> <span style=''>of</span> <span style=''>Gradient</span> <span style=''>Descent</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>This</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>deep</span> <span style=''>insight</span> <span style=''>for</span> <span style=''>its</span> <span style=''>faster</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>convergence</span> <span style=''>rate</span> <span style=''>under</span> <span style=''>optimal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameter</span> <span style=''>tuning</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>conjecture</span> <span style=''>that</span> <span style=''>this</span> <span style=''>gain</span> <span style=''>is</span> <span style=''>always</span> <span style=''>present</span> <span style=''>as</span> <span style=''>opposed</span> <span style=''>to</span> <span style=''>the</span> <span style=''>lifting</span> <span style=''>of</span> <span style=''>a</span> <span style=''>Markov</span> <span style=''>chain</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>sometimes</span> <span style=''>only</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>marginal</span> <span style=''>speedup</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Robustness</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Regularization</span> <span style=''>of</span> <span style=''>Support</span> <span style=''>Vector</span> <span style=''>Machines</span> <br/><br/><span style=''>We</span> <span style=''>consider</span> <span style='background-color:rgba(255, 0, 0, 0.30496453900709214);'>regularized</span> <span style=''>support</span> <span style=''>vector</span> <span style=''>machines</span> <span style=''>(SVMs)</span> <span style=''>and</span> <span style=''>show</span> <span style=''>that</span> <span style=''>they</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>precisely</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>equivalent</span> <span style=''>to</span> <span style=''>a</span> <span style=''>new</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalence</span> <span style=''>of</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>implications</span> <span style=''>for</span> <span style=''>both</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>and</span> <span style=''>analysis</span> <span style=''>In</span> <span style=''>terms</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalence</span> <span style=''>suggests</span> <span style=''>more</span> <span style=''>general</span> <span style=''>SVM</span> <span style=''>like</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classification</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explicitly</span> <span style=''>build</span> <span style=''>in</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>protection</span> <span style=''>to</span> <span style=''>noise</span> <span style=''>and</span> <span style=''>at</span> <span style=''>the</span> <span style=''>same</span> <span style=''>time</span> <span style=''>control</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>overfitting</span> <span style=''>On</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>front</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>equivalence</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>robustness</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>regularization</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>robust</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>for</span> <span style=''>the</span> <span style=''>success</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.30496453900709214);'>regularized</span> <span style=''>SVMs</span> <span style=''>We</span> <span style=''>use</span> <span style=''>the</span> <span style=''>this</span> <span style=''>new</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>robustness</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpretation</span> <span style=''>of</span> <sp ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Proximal</span> <span style=''>Methods</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Hierarchical</span> <span style=''>Sparse</span> <span style=''>Coding</span> <br/><br/><span style=''>Sparse</span> <span style=''>coding</span> <span style=''>consists</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>representing</span> <span style=''>signals</span> <span style=''>as</span> <span style=''>sparse</span> <span style=''>linear</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>combinations</span> <span style=''>of</span> <span style=''>atoms</span> <span style=''>selected</span> <span style=''>from</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>dictionary</span> <span style=''>We</span> <span style=''>consider</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extension</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>where</span> <span style=''>the</span> <span style=''>atoms</span> <span style=''>are</span> <span style=''>further</span> <span style=''>assumed</span> <span style=''>to</span> <span style=''>be</span> <span style=''>embedded</span> <span style=''>in</span> <span style=''>a</span> <span style=''>tree</span> <span style=''>This</span> <span style=''>is</span> <span style=''>achieved</span> <span style=''>using</span> <span style=''>a</span> <span style=''>recently</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduced</span> <span style=''>tree</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>structured</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularization</span> <span style=''>norm</span> <span style=''>which</span> <span style=''>has</span> <span style=''>proven</span> <span style=''>useful</span> <span style=''>in</span> <span style=''>several</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>applications</span> <span style=''>This</span> <span style=''>norm</span> <span style=''>leads</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>problems</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficult</span> <span style=''>to</span> <span style=''>optimize</span> <span style=''>and</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>in</span> <span style=''>this</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithms</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>them</span> <span style=''>More</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>precisely</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>the</span> <span style=''>proximal</span> <span style=''>operator</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>this</span> <span style=''>norm</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computable</span> <span style=''>exactly</span> <span style=''>via</span> <span style=''>a</span> <span style=''>dual</span> <span style=''>approach</span> <span style=''>that</span> <span style=''>can</span> <span style=''>be</span> <span style=''>viewed</span> <span style=''>as</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>composition</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>elementary</span> <span style=''>proximal</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operators</span> <span style=''>Our</span> <span style= ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	challenging (0.09372772630078403)
# 	representation (0.12900926585887385)
# 	architecture (0.08054169636493229)
# 	experimental (0.1436208125445474)
# 	segmentation (0.0698503207412687)
# 	different (0.2573057733428368)
# 	information (0.2419814682822523)
# 	detection (0.12045616535994298)
# 	recognition (0.1397006414825374)
# 	convolutional (0.14682822523164646)
#
# Some Statistics words are:
# 	distributions (0.1213640922768305)
# 	variational (0.10230692076228685)
# 	estimation (0.1715145436308927)
# 	statistical (0.14543630892678033)
# 	theoretical (0.1469408224674022)
# 	distribution (0.1860581745235707)
# 	inference (0.19759277833500502)
# 	algorithm (0.3981945837512538)
# 	dimensional (0.18405215646940823)
# 	regression (0.18405215646940823)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b48af70d-c742-4766-8e96-785f93e281c5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b48af70d-c742-4766-8e96-785f93e281c5")) {                    Plotly.newPlot(                        "b48af70d-c742-4766-8e96-785f93e281c5",                        [{"x":["stationary","parameterized","condition","arbitrarily","objective","generated","distributions","plausible","graphical","encourages","biological","experimental","dynamical","distribution","illustrating","transition","operators","stochastic","trajectories","continues","guarantee","traditional","symmetric","corresponding","biologically","trajectory","application","undirected","variational","equilibrium","expressing","indirectly","soundness","asymmetric","restrictive","principled","recurrent","demonstrating","comparable","equivalent","discounted","negligible","different","solutions","obtaining","magnitude","functions","specified","important","algorithm","characterization","equations","essentially","qualitatively","optimizing","differential","classical","sequences","algorithms","predicting","simultaneously","aggregate","quantitative","complementary","prediction","integrated","parameters","contextual","attention","innovations","highlight","framework","effectively","specifically","detection","introduce","evaluation","qualitative","mechanism","significantly","convolutional","performance","benchmarks","aggregating","considered","establishing","presented","including","intelligence","instances","relaxation","convergence","potential","segmentation","properties","applicability","affiliation","contribution","leveraging","artificial","probabilistic","strategies","introduced","introduces","coordination","economics","literature","existence","engineering","interaction","distinguishes","distributed","congestion","allocation","equilibria","characterizations","originally","particularly","judgments","investigate","approaches","historical","optimized","appropriate","paintings","measuring","available","availability","aesthetic","digitized","classification","essential","multimedia","providing","collections","experiments","similarity","comprehensive","interpretation","knowledge","aforementioned","architecture","generalization","recognize","predefined","background","proposing","spatially","explicitly","commercial","experienced","suitability","interactions","localizing","illumination","localization","intuition","exploited","unrealistic","necessary","deployment","categories","applications","adaptation","conditions","flexibility","rationale","effectiveness","computational","techniques","information","incorporate","regression","regularization","efficiency","supervised","correctness","substantial","nonlinear","structure","statistical","unfortunately","representations","demonstrate","difficult","multilingual","discussed","sometimes","challenges","convenience","themselves","occasions","challenging","processing","analyzing","classifiers","preserved","misclassified","identification","platforms","languages","communication","sentiment","rectified","competitive","verification","experiment","consistent","relationship","representation","bootstrapping","embedding","informative","threshold","recognition","accordingly","convolution","selection","implemented","development","activation","suppresses","inaccurate","ambiguous","developing","successful","discipline","dissertation","components","translating","construct","concerned","environments","translation","translations","automated","typically","challenge","expensive","resources","scalability","alternatives","computing","bilingual","constrained","particular","projected","demonstrates","discriminative","adversarial","theoretical","capability","guarantees","generati ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	randomforest
# 	tibshirani
# 	suboptimality
# 	unsuccessful
# 	physiologic
# 	pseudolikelihood
# 	extrapolation
# 	subpopulations
# 	ellipsoids
# 	inductively
# 	metastable
# 	sparsities
# 	grassmannian
# 	descendant
# 	collaborators
# 	specialist
# 	imaginary
# 	autoencoding
# 	attributing
# 	inhomogeneity
# Some words which never appear in Statistics papers:
# 	digitized
# 	localizing
# 	illumination
# 	occasions
# 	misclassified
# 	bilingual
# 	nonmonotonic
# 	unlearnable
# 	grammatical
# 	prematurely
# 	categorial
# 	reshuffling
# 	mastering
# 	transducer
# 	corollaries
# 	compilation
# 	professionals
# 	phenomenological
# 	memristors
# 	memristor

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0662619200932145e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7433333333333333
